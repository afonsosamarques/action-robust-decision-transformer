# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datasets import load_dataset, load_from_disk
from huggingface_hub import login

#
import warnings
warnings.filterwarnings('ignore')

# import sys
# import os
# dir = os.path.abspath('')
# while not dir.endswith('ardt'): dir = os.path.dirname(dir)
# if not dir in sys.path: sys.path.append(dir)
# from access_tokens import HF_WRITE_TOKEN

# %%
dataset_name = "trpo_halfcheetah_train"
dataset = load_from_disk(f"./datasets/{dataset_name}")
dataset
# Out:
# Dataset({
#     features: ['observations', 'actions', 'rewards', 'dones'],
#     num_rows: 1001
# })

# %%
returns = (np.array(dataset['rewards'])).sum(axis=1)
sns.distplot(returns);

# %%
actions = np.array(dataset['actions'])
for i in range(actions.shape[2]):
    print("===============================")
    # print("Action dimension: ", i+1)
    # print("Min:", np.min(actions[:, :, i]))
    # print("Median:", np.median(actions[:, :, i]))
    # print("Max:", np.max(actions[:, :, i]))
    # print("Mean:", np.mean(actions[:, :, i]))
    plt.figure()
    sns.displot(actions[:, :, i].reshape(-1, 1).squeeze())
    plt.show();
